# %%
import io
from IPython.nbformat import current

def execute_notebook(nbfile):
    
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    
    ip = get_ipython()
    
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)

# %%
execute_notebook("GUI Selections for OIII and Ha.ipynb")
# Out:
# array([[  0, 281],
#        [  1, 844],
#        [  2, 522]], dtype=int64)
# array([[  0, 203],
#        [  1, 204],
#        [  2, 258]], dtype=int64)
# array([[-27.959742,   1.      ],
#        [-27.959642,   1.      ],
#        [-27.958683,   1.      ],
#        ...,
#        [-27.655918,   1.      ],
#        [-27.655844,   1.      ],
#        [-27.655812,   1.      ]])
# [12275 14266 14320 ..., 11394 11788 13231]
# ['aegis' 'aegis' 'aegis' ..., 'uds' 'uds' 'uds']
# [1 1 1 ..., 1 2 2]
# [['aegis' '356']
#  ['cosmos' '252']
#  ['goodsn' '316']
#  ['goodss' '337']
#  ['uds' '386']]
# array([[-27.959742,   1.      ],
#        [-27.959642,   1.      ],
#        [-27.958683,   1.      ],
#        ...,
#        [-27.655918,   1.      ],
#        [-27.655844,   1.      ],
#        [-27.655812,   1.      ]])
# array([[    0, 38080],
#        [    1,   199]], dtype=int64)
# array([[    0, 38258],
#        [    1,    21]], dtype=int64)
# array([[    0, 38245],
# ...

# %%
uv = fits.open('uvudf_rafelski_2015.fits', memmap=True)[1].data

# %%
np.array(zip(uv['ra'], uv['dec']))
# Out:
# array([[ 53.16550813, -27.8284858 ],
#        [ 53.16386184, -27.8306808 ],
#        [ 53.16459659, -27.83115894],
#        ...,
#        [ 53.14831586, -27.77469665],
#        [ 53.16278047, -27.78222953],
#        [ 53.13304337, -27.78445849]])

# %%
south_address = np.array(zip(south_data['id'], south_data['ra'], south_data['dec']))
uv_address = np.array(zip(uv['id'],uv['ra'],uv['dec']))

# %%
south_address[match( 53.16459659,-27.83115894, 0.0002)]
# Out:
# array([], shape=(0L, 3L), dtype=float64)

# %%
def match(ra,dec, thresh):
    return ((south_data['ra'] < ra+thresh) & (south_data['ra'] > ra-thresh) & (south_data['dec'] > dec-thresh) & (south_data['dec'] <dec+thresh))

# %%
match_cats_1 = np.array([south_data['id'][match(x,y,0.00005)] for x,y in zip(uv['ra'],uv['dec'])])
match_cats_2 = np.array([south_data['id'][match(x,y,0.000025)] for x,y in zip(uv['ra'],uv['dec'])])
match_cats_3 = np.array([south_data['id'][match(x,y,0.0000125)] for x,y in zip(uv['ra'],uv['dec'])])

matched_cats_1 = np.array([x[0] if (len(x)==1) else -1 if (len(x)>1) else -99 for x in match_cats_1])
matched_cats_2 = np.array([x[0] if (len(x)==1) else -1 if (len(x)>1) else -99 for x in match_cats_2])
matched_cats_3 = np.array([x[0] if (len(x)==1) else -1 if (len(x)>1) else -99 for x in match_cats_3])
print scipy.stats.itemfreq(matched_cats_1)
print scipy.stats.itemfreq(matched_cats_2)
print scipy.stats.itemfreq(matched_cats_3)
# Out:
# [[  -99  5267]
#  [17405     1]
#  [17451     1]
#  ...,
#  [34257     1]
#  [34299     1]
#  [34323     1]]
# [[  -99  5657]
#  [17405     1]
#  [17451     1]
#  ...,
#  [34249     1]
#  [34299     1]
#  [34323     1]]
# [[  -99  6950]
#  [17405     1]
#  [17451     1]
#  ...,
#  [33983     1]
#  [33992     1]
#  [34299     1]]

# %%
matched_cats_4= np.array([-99 if (x==-99) else t if t>0 else b[0] if y>0 else a[0] if x>0 else -99 for x,y,t,a,b in zip(matched_cats_1,matched_cats_2,matched_cats_3,match_cats_1,match_cats_2)])
scipy.stats.itemfreq(matched_cats_4)
# Out:
# array([[  -99,  5267],
#        [17405,     1],
#        [17451,     1],
#        ...,
#        [34257,     1],
#        [34299,     1],
#        [34323,     1]], dtype=int64)

# %%
check_freqs= np.array([scipy.stats.itemfreq(matched_cats_4)[x][1] for x in range(0, len(scipy.stats.itemfreq(matched_cats_4)))])
check_items = np.array([scipy.stats.itemfreq(matched_cats)[x][0] for x in range(0, len(scipy.stats.itemfreq(matched_cats)))])
scipy.stats.itemfreq(check_freqs)
# Out:
# array([[   1, 4606],
#        [   2,   48],
#        [5267,    1]], dtype=int64)

# %%
lookup = {}
for freqs, items in np.array(zip(check_freqs,check_items)):
    lookup[items]=freqs

# %%
lookup
# Out:
# {24577: 1,
#  24578: 1,
#  24580: 1,
#  24583: 1,
#  24584: 1,
#  32777: 1,
#  24586: 1,
#  24587: 1,
#  31643: 2,
#  24589: 1,
#  24590: 1,
#  24592: 1,
#  30040: 1,
#  24595: 1,
#  24596: 1,
#  24597: 1,
#  32790: 1,
#  24599: 1,
#  24600: 1,
#  24604: 1,
#  24609: 1,
#  24614: 1,
#  24615: 1,
#  24616: 1,
#  24617: 1,
#  24618: 1,
#  24619: 1,
#  24620: 1,
#  24621: 1,
#  24622: 1,
#  24625: 1,
#  24626: 1,
#  24628: 1,
#  24629: 1,
#  24630: 1,
#  29735: 1,
#  24635: 1,
#  28644: 1,
#  32831: 1,
#  24640: 1,
#  24641: 1,
#  24642: 1,
#  24644: 1,
#  32839: 1,
#  31645: 1,
#  24649: 1,
#  24650: 1,
#  24652: 1,
#  28685: 1,
#  24658: 1,
#  24660: 1,
#  32191: 1,
#  24663: 1,
#  27281: 1,
#  24670: 1,
#  30053: 1,
#  24673: 1,
#  24674: 1,
#  24675: 1,
#  24676: 1,
#  24678: 1,
#  32871: 1,
#  24680: 1,
#  24681: 1,
#  24683: 1,
#  24685: 1,
#  29464: 1,
#  24689: 1,
#  24690: 1,
#  24691: 1,
#  32192: 1,
#  24694: 1,
#  24695: 1,
#  24696: 1,
#  24697: 1,
#  32890: 1,
# ...

# %%
south_address[south_data['id']==31643]
# Out:
# array([[  3.16430000e+04,   5.31618950e+01,  -2.77669210e+01]])

# %%
def reverse_match(ra,dec, thresh):
    return ((uv['ra'] < ra+thresh) & (uv['ra'] > ra-thresh) & (uv['dec'] > dec-thresh) & (uv['dec'] <dec+thresh))

# %%
uv_address[reverse_match(5.31618950e+01, -2.77669210e+01, 0.0001)]
# Out:
# array([[ 24365.        ,     53.16188653,    -27.76688765],
#        [ 24375.        ,     53.16193196,    -27.76694832]])

# %%
np.max(matched_cats_4)
# Out:
# 34323

# %%
z = np.concatenate((aegis_lines['z'], cosmos_lines['z'], north_lines['z'], south_lines['z'], uds_lines['z']))

# %%
z_uv = np.array([-99 if ki==-99 else z[113358:163865][ki] for ki in matched_cats_4])
spec_uv = np.array([-99 if ti==-99 else south_data['z_spec'][ti] for ti in matched_cats_4])

# %%
south_id = np.array([-99 if ti==-99 else south_data['id'][ti] for ti in matched_cats_4])
south_use = np.array([-99 if ti==-99 else south_data['use_phot'][ti] for ti in matched_cats_4])
package= np.array(zip(uv['id'], south_id, z_uv, spec_uv, south_use))

# %%
scipy.stats.itemfreq(((z_uv > 2.512) | (spec_uv>2.512)) & (uv['flux_f275w']> 5*uv['fluxerr_f275w']))
# Out:
# array([[   0, 9961],
#        [   1,    8]], dtype=int64)

# %%
package[(((z_uv > 2.512) | (spec_uv>2.512)) & (uv['flux_f275w']> 5*uv['fluxerr_f275w']))]
# Out:
# array([[  3.04100000e+03,   2.34270000e+04,   2.63460000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  4.41600000e+03,   3.34610000e+04,   3.53353000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  4.78200000e+03,   2.66220000e+04,   2.85550000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  8.24500000e+03,   2.93240000e+04,   2.61286000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  9.01000000e+03,   3.07780000e+04,   2.57691000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  9.52800000e+03,   2.96160000e+04,   3.07960000e+00,
#          -1.00000000e+00,   0.00000000e+00],
#        [  2.29840000e+04,   2.56530000e+04,   2.74717000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  2.45300000e+04,   3.10640000e+04,   2.67848000e+00,
#          -1.00000000e+00,   0.00000000e+00]])

# %%
uv['flux_f336w'][uv['id']==4416] >5* uv['fluxerr_f336w'][uv['id']==4416]
# Out:
# array([ True], dtype=bool)

# %%
(380/91.6)-1
# Out:
# 3.148471615720524

# %%
4.08 * 91.6
# Out:
# 373.728

# %%
uv['flux_f225w'][uv['id']==9528] >5* uv['fluxerr_f225w'][uv['id']==9528]
# Out:
# array([ True], dtype=bool)

# %%
uv['z_eazy'][(((z_uv > 2.512) | (spec_uv>2.512)) & (uv['flux_f275w']> 5*uv['fluxerr_f275w']))]
# Out:
# array([ 1.36619997,  0.80510002,  0.3229    ,  1.35950005,  0.77749997,
#         0.61269999,  0.22849999,  1.00510001])

# %%
(300/91.6)-1
# Out:
# 2.275109170305677

# %%
scipy.stats.itemfreq(((z_uv > 2.275) | (spec_uv>2.275)) & (uv['flux_f225w']> 5*uv['fluxerr_f225w']))
# Out:
# array([[   0, 9958],
#        [   1,   11]], dtype=int64)

# %%
package[(((z_uv > 2.275) | (spec_uv>2.275)) & (uv['flux_f225w']> 5*uv['fluxerr_f225w']))]
# Out:
# array([[  3.04100000e+03,   2.34270000e+04,   2.63460000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  4.41600000e+03,   3.34610000e+04,   3.53353000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  4.78200000e+03,   2.66220000e+04,   2.85550000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  6.79300000e+03,   2.72500000e+04,   2.78104000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  8.24500000e+03,   2.93240000e+04,   2.61286000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  9.01000000e+03,   3.07780000e+04,   2.57691000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  9.04000000e+03,   2.96330000e+04,   2.31680000e+00,
#          -1.00000000e+00,   1.00000000e+00],
#        [  9.52800000e+03,   2.96160000e+04,   3.07960000e+00,
#          -1.00000000e+00,   0.00000000e+00],
#        [  2.15140000e+04,   2.39060000e+04,   2.68032000e+00,
#          -1.00000000e+00,   1.00000000e+00],
# ...
